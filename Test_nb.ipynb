# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 10, 0.05)
y = np.sin(x)

# %%
plt.figure(figsize=(15,10))
plt.plot(x, y)
plt.show()

# %% [markdown]
# $$\int_\limits0^{\infty} \frac 1 {k+1} = 228$$

# %% [markdown]
# $$\sum_{k=n_0}^{\infty} \frac{1}{k^2-k-z} \le \sum_{k=n_0}^{\infty} \frac{1}{k^2-2k+1} \le \int_{n_0}^{\infty} \frac 1 {(k-1)^2}, k \ge 3 $$
#
# $$ \int_{n_0}^{\infty} \frac 1 {(k-1)^2} = \frac 1 {n_0-1} $$
#
# Таким образом, для достижения точности $\varepsilon$ потребуется по меньшей мере $\frac{1}{\varepsilon} + 1$ слагаемое, то есть порядка $10^6$ в нашем случае
